# %% [markdown]
# # **Herzlich willkommen zum Girls Day mit *starcode!**
#
#
# Heute werden wir mit Python und Künstlicher Intelligenz Bilder verarbeiten!
#
# Viel Spaß!

# %% [markdown]
# # Python 🐍
#
# Python ist eine beliebte Programmiersprache. Man benutzt sie um **Code** zu schreiben, das heißt, dem Computer Befehle zu geben.
#
# Das kann man zum Beispiel in Notebooks wie diesem hier machen.
# Die grau gefärbten Zeilen sind **Code-Blöcke**.
# Diese kannst du ausführen, das heißt, der Computer macht, was du im Code beschreibst.

# %% [markdown]
# ⭐ <font color='sky blue'>*Aufgabe: Führe diesen Code-Block aus in dem du auf den Playbutton ▶ klickst.*

# %%
print("Hello World!")

# %% [markdown]
# print() ist ein sogenannter **Befehl**. Es gibt viele verschiedene Befehle, die
# dem Computer sagen, was er machen soll. Der print()-Befehl sagt, er soll den Inhalt der Klammern ausgeben, also einfach anzeigen.
#
# In dem du den Inhalt in den Klammern veränderst, kannst du dir auch andere Sachen ausgeben lassen.

# %% [markdown]
# ⭐ <font color='sky blue'> *Aufgabe: Gib deinen eigenen Namen aus!*

# %% [markdown]
# *kurze Info: Der Computer nimmt alles sehr genu und verzeiht keine Rechtschreibfehler in den Befehlen. Falls es nicht geklappt hat, überprüfe, ob **print** richtig geschrieben ist, und ob du die Klammern und auch die Anführungszeichen benutzt hast*

# %% [markdown]
# ## Kommentare
#
# Codezeilen mit einem **#** davor werden nicht ausgeführt. Man nennt sie *Kommentare*, denn man kann damit seinen Code mit Erkärungen kommentieren, sodass andere ihn verstehen können. Wenn man **#** hinter eine Codezeile schreibt, wir der Rest der Zeile auch ignoriert. <br> Hier ein Beispiel:

# %%
# Das ist ein Kommentar.

# %%
print("Diese Zeile wird ausgeführt")  # aber nur bist zum "#"

# %% [markdown]
# ## Variablen
#
# **Variablen** sind wie Boxen, in die man Dinge reinlegt. Jede Box hat einen Namen und einen Inhalt.
#
# \<Name der Box> = \<Inhalt der Box>
#
# Zum Beispiel:

# %%
meine_lieblingszahl = 7

# %% [markdown]
# Der Computer speichert jetzt die 7 mit dem Namen "meine_lieblingszahl". Das heißt, wenn man eine 7 schreiben möchte, kann man stattdessen auch meine_lieblingszahl dazu sagen.
#
# Wenn du wissen willst, welche Zahl gerade unter "meine_lieblingszahl" gespeichert ist, kannst du wieder den print()-Befehl nutzen, um sie dir anzeigen zu lassen. Dafür musst du nur "meine_lieblingszahl" in die Klammer hinter print() schreiben.
#
# Hier kannst du es einmal ausprobieren:

# %%
print(meine_lieblingszahl)

# %% [markdown]
# ⭐ <font color='sky blue'> *Aufgabe: Führe diesen Code-Block aus und ändere die Zahl zu einer, auf die du Lust hast!*

# %%
meine_lieblingszahl=19

# %% [markdown]
# Du kannst einen Computer wie einen großen Taschenrechner benutzen. Zum Beispiel kannst du mit der Variable von oben rechnen.

# %% [markdown]
#  ⭐ <font color='sky blue'> *Aufgabe: Führe diesen Code-Block aus und lass den Computer für dich rechnen. Du kannst einfach alles hinschreiben, was du möchtest (plus +  minus-   mal *  geteilt / ), Punkt vor Strichrechnung wird automatisch beachtet*

# %%
meine_lieblingszahl + 3

# %% [markdown]
# ⭐ <font color='sky blue'>  *Definiere eine Variable mit dem Namen "jahr" und befülle sie mit der Zahl 2023.*
#
# \<Name der Variable> = \<Inhalt der Variable>

# %% [markdown]
# # Künstliche Intelligenz (KI) 🤖

# %% [markdown]
# Künstliche Intelligenz (KI) ist ein Computer Programm, das Aufgaben selbstständig lösen kann. Eine KI kann zum Beispiel lernen, Schach zu spielen.
#
# In "normalen" Programmen gibt der Mensch im Code den Lösungsweg vor. Der Computer folgt quasi nur Befehlen.
# Bei einer KI gibt der Mensch ein Problem vor und die KI entscheidet, was passiert und "lernt". Eine KI, die Schach spielen kann, lernt selbstständig zu entscheiden, wie sie auf die Schachzüge des Gegenspielers reagieren muss.
#
# Um zu lernen braucht die KI Daten. Eine Schach KI braucht Daten über die vorherigen Schachspiele: welche Züge hat der Gegner gemacht, welche Züge hat die KI gemacht, und wie ist das Spiel ausgegangen. Die Daten kann die KI analysieren. Wir als Menschen müssen der KI die Daten geben.

# %% [markdown]
# # Bilder verarbeiten

# %% [markdown]
# ⭐ <font color='sky blue'>  *Aufgabe: Führe den nächsten Code-Block aus! Denn erst dann kannst du die Felder weiter unten starten*

# %%
#@title Befehle { display-mode: "form" }
# loading libraries
from skimage import segmentation, color, io
from skimage.future import graph
from skimage.transform import rescale, resize
from skimage.segmentation import mark_boundaries
from skimage.filters import sobel
from sklearn.cluster import KMeans
from skimage.future import graph
from matplotlib import pyplot as plt
from io import BytesIO
from PIL import Image
from ipywidgets import FileUpload
from IPython.display import display
from collections import Counter
from functools import reduce
import numpy as np
import urllib.request
import os


# segmentation params
compactness = 10
segment_count = 2000
sigma = 3
theshold = 10
border_color = np.array([50, 50, 50])

def foto_hochladen(number):
  if number == 1:
    urllib.request.urlretrieve("https://img.freepik.com/fotos-premium/luftbild-ueber-berlin-in-deutschland-auf-einem-sonnenuntergang_87646-4849.jpg","image.jpg")
  if number == 2:
    urllib.request.urlretrieve("https://wallpapers.com/images/hd/artwork-of-frida-kahlo-representing-a-mexican-woman-ynl9bzx20d4bgx50.jpg","image.jpg")
  if number == 3:
    urllib.request.urlretrieve("https://i.pinimg.com/564x/77/34/fa/7734fa75249ff031476fd18b93249d6f.jpg","image.jpg")
  if number == 4:
    urllib.request.urlretrieve("https://i.pinimg.com/564x/6e/96/87/6e96879ee85f507c1b2d274ac1289d50.jpg","image.jpg")
  if number == 5:
    urllib.request.urlretrieve("https://64.media.tumblr.com/43f7e479ea57be4fc1bfdb5e133390ff/tumblr_p25sdpqVun1un8qsqo6_1280.jpg","image.jpg")
  #img = Image.open('/content/image.jpg')
  
  dir = os.path.abspath(os.getcwd())
  img = Image.open(dir + '/image.jpg')
  array = np.asarray(img)
  plt.imshow(array)
  return array

def foto_speichern(upload):
  # convert uploaded byte image into array
  byte_image = list(upload.value.values())[0]['content']
  image = np.array(Image.open(BytesIO(byte_image)))
  plt.imshow(image)
  return image

def pixel_gruppieren(image):
  # segment image
  slic_labels = segmentation.slic(image, compactness=compactness,
                            n_segments=segment_count,
                            start_label=1,
                            sigma=sigma)

  slic_img = color.label2rgb(slic_labels, image, kind='avg', bg_label=0).astype(int)
  #plt.imshow(slic_img)

  # construct RAG from segmented image
  g = graph.rag_mean_color(image, slic_labels)

  # RAG regions that are similar will be merged
  rag_labels = graph.cut_threshold(slic_labels, g, theshold)

  # show image with grouped colors
  rag_img = color.label2rgb(rag_labels, image, kind='avg', bg_label=-1).astype(int)
  plt.imshow(rag_img)

  return rag_img

def kmeans(rag_img,color_count):
  # kmeans for color reduction
  arr = rag_img.reshape((-1, 3))
  kmeans = KMeans(n_clusters=color_count,n_init='auto').fit(arr)
  kmean_labels = kmeans.labels_
  centers = kmeans.cluster_centers_
  kmeans_img = centers[kmean_labels].reshape(rag_img.shape).astype('uint8')

  plt.figure(figsize=(10, 10))
  plt.subplot(2,1,1)
  plt.imshow(kmeans_img)

  plt.imsave(f'goal.png', kmeans_img)

  # show color palette
  plt.subplot(2,1,2)
  plt.title(f'Die {color_count} häufigsten Farben im Bild')
  plt.imshow([centers.astype('int')])
  plt.axis('off')

  return kmeans_img

def umrisse_zeichnen(image,kmeans_img):
  white_image = np.ones_like(image)*255
  gray_kmeans = color.rgb2gray(kmeans_img)
  min = np.min(gray_kmeans)
  max = np.max(gray_kmeans)
  normalized_grayscale_img = ((gray_kmeans - min)*(255/(max-min))).astype('int')
  kmeans_borders = mark_boundaries(white_image, normalized_grayscale_img, border_color/255)
  plt.imshow(kmeans_borders)
  plt.imsave(f'canvas.png', np.clip((kmeans_borders+0.6), 0, 1))

# %% [markdown]
# Hier sind nun ein paar Bilder angezeigt, auf die wir später zugreifen können.

# %% [markdown]
# Bild 1:

# %% [markdown]
# ![Berlin_klein.png](data:image/png;base64,...)

# %% [markdown]
# Bild 2:

# %% [markdown]
# ![FridaKahlo.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild 3:

# %% [markdown]
# ![katze_klein.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild 4:

# %% [markdown]
# ![sunflower_klein.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild 5:

# %% [markdown]
# ![image_6483441_klein.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Um mit einem Bild arbeiten zu können, müssen wir es erst dem Computer übergeben. Das geht mit den variablen, die oben kurz erklärt wurden. Dem Computer kann ein Bild mit dem Befehl foto_hochladen() übergeben werden, dabei muss die Nummer des jeweiligen Bildes in die Klammer geschrieben werden. Das Foto bekommt dann noch einen Namen, hier "foto"

# %% [markdown]
# ⭐ <font color='sky blue'>  *Aufgabe: Such dir eines der Bilder aus und schreibe die Nummer in die Klammern.*

# %%
foto = foto_hochladen(2)

# %% [markdown]
# Du kannst dir auch selbt ein Bild aussuchen und hochladen. Dafür musst du einmal den Code laufen lassen und danach erscheint ein Button, auf dn du klicken kannst. Dann kannst du ein Bild aussuchen, das vorher runtergeladen wurde.

# %%
upload = FileUpload(accept='image/*', multiple=True)
print("Bitte lade hier ein Foto hoch")
display(upload)

# %% [markdown]
# Um mit deinem eigenen Bild weiterzuarbeiten, musst du nochmal den Befehl hier ausführen. Der Befehl ordnet dem Bild wieder den Namen "foto" zu

# %%
foto = foto_speichern(upload)

# %% [markdown]
# ## Pixel 🍬
#
# Computerbildschirme und die Bilder, die sie zeigen, bestehen aus Pixeln. Pixel sind kleine farbige Bildpunkte, die in Zeilen und Spalten angeordnet sind. Hier ist ein Beispiel einer Wassermelone abgebildet. Um später aus unseren eigenen Bildern ein Ausmalbild zu erstellen, müssen wir die Pixelstruktur der Bilder anschauen.

# %% [markdown]
# ![water-melon.png](data:image/png;base64,...)

# %% [markdown]
# # Gruppieren (Clustern)
#
# Gruppieren bedeutet etwas in Gruppen mit **ähnlichen Eigenschaften** zusammenzufassen.
# Das nennt mant auf Englisch "**Clustern**".
#
#
#
#
# Clustern ist eine wichtige Technik in der Künstlichen Intelligenz, bei der der Computer selbstständig herausfindet, welche Elemente in einer Gruppe zusammengefasst werden können.
# Für ein Ausmalbild müssen wir Pixel gleicher Farbe zusammengruppieren.

# %% [markdown]
# ## Pixel gruppieren

# %% [markdown]
# Wir können die Pixel in unserem Bild clustern. Dabei fassen wir Pixel, die eine ähnliche Farbe haben und nebeneinander liegen, in Gruppen zusammen.

# %% [markdown]
# ⭐ <font color='sky blue'>  *Aufgabe: Lege eine Variable an und nenne sie "foto_gruppiert". Rufe dann den Befehl **pixel_gruppieren()** auf. Gib dem Befehl in den Klammern die Variable **foto**.*

# %% [markdown]
# <font color='sky blue'> Was fällt dir an diesem bearbeitetem Foto im Gegensatz zum Original auf?

# %% [markdown]
# ## Farben clustern

# %% [markdown]
# In unserem letzten Bild gibt es noch sehr viele verschiedene Farben. Die müsstest du alle anmischen, um das Bild zu malen. In dem wir die Farben clustern, könne wir deren Anzahl zu reduzieren. Farben clustern heißt hier, ähnliche Farben zu einer zusammenzufassen. Wie das geht, wird kurz im nächsten Abschnitt erklärt.

# %% [markdown]
# ### K-means

# %% [markdown]
# K-means ist ein Algorithmus, der herausfindet, welche Datenpunkte in eine Guppe gehören.
# Man kann festlegen, in wie viele Gruppen die Daten eingeteilt werden soll.

# %% [markdown]
# ![k-Means-cluster.png](data:image/png;base64,...)

# %% [markdown]
# *Aufgabe: Rufe den Befehl **kmeans()** auf, und gib ihm in den Klammern das gruppierte Foto und die Zahl 10.*

# %%
#kmeans_foto = kmeans(foto_gruppiert,10)

# %% [markdown]
# Hier wurden das Bild jetzt auf 10 unterschiedliche Farben reduziert.

# %% [markdown]
# # Umrisse zeichen

# %% [markdown]
# Jetzt kommt der letzte Schritt! Wir müssen nur noch die Umrisse der Farbgruppen zeichnen.

# %% [markdown]
# *Aufgabe: Rufe den Befehl umrisse_zeichnen() auf. In den Klammern musst du dem Befehl das Original Foto und das mit K-means geclusterte Foto übergeben.*

# %%
#umrisse_zeichnen(foto,kmeans_foto)

# %% [markdown]
# Fertig ist dein Malen-Nach-Zahlen Bild!

# %% [markdown]
# Du kannst dein fertiges Bild in der Leiste auf der linken Seite runterladen!
#
# Klicke dafür links auf das Ordner Symbol:

# %% [markdown]
# ![Screenshot 2023-05-06 000811.png](data:image/png;base64,...)

# %% [markdown]
# Dort siehst du dann die Fotos! Canvas.png ist die schwarz-weiße Vorlage zum Ausdrucken und goal.png ist das kmeans Foto, auf dem du die Farben für die Felder siehst.

# %% [markdown]
# ![Screenshot 2023-05-06 000737.png](data:image/png;base64,...)

# %% [markdown]
# Wir würden uns freuen, wenn wir dich bald in einem unserer Kurse bei *starcode wiedersehen!
#
# Falls dir der kleine Einblick ins Programmieren gefallen hat, schau gerne auf unsere Website https://www.starcode.de/ Ausschau nach neuen Kursen.
#
# Dort werden wir an das anknüpfen, was wir am Girls Day gelernt haben. Wir werden in diesem Kurs mehr Zeit haben und Python ausführlicher kennenlernen.

# %% [markdown]
# # **Falls du noch mehr wissen möchtest: Funktionen 🪄**
#
# Vielleicht hast du dich schon gefragt, woher die Befehle wie `pixel_gruppieren`,`foto_hochladen()`, `foto_speichern()`ubd auch `print()` eigentlich kommen. Die Antwort ist ganz einfach: Jemand hat sie erfunden!<br> Diese Befehle, die wir auch Funktionen nennen, sind Anweisungen, die der Computer versteht und ausführt. Und das Beste ist, dass wir solche Funktionen ganz einfach selbst erfinden können!
#
# In Python kannst du eine Funktion mit dem Wort `def` definieren. Führe einmal den nächsten Codeabschnitt aus.

# %%
def sag_hallo():
  print('Hallo!')

# %% [markdown]
# Ist gar nichts passiert? Doch! Python weiß jetzt, wie die Funktion `sag_hallo()` aussieht, du hast sie allerdings noch nicht aufgerufen. Aufrufen bedeutet, dass die Funktion ausgeführt wird. Du schreibst dafür den Funktionsnamen, gefolgt von Klammern auf.

# %%
sag_hallo()

# %% [markdown]
# Die Funktionen, um das Malen nach Zahlen Bild zu erstellen, haben wir in diesem Dokument erst erfunden und definiert. Wenn du sehen möchtest, wie wir das gemacht haben, öffne den erste Codeblock ganz oben, direkt und ter Überschrift "Bilder bearbeiten". Da sind alle Dinge definiert, die du gerade benutzt hast. Findest du etwas wieder?

# %% [markdown]
# # Hier kannst du mehr Programmieren und über Informatik lernen!
#
# *   In den Kursen von *starcode: https://www.starcode.de/
# *   Spiel Code Combat https://codecombat.com/play/dungeon
# *   Code it https://code-it-studio.de/
# *   Code.org https://studio.code.org/courses
# *   Clustering erklärt: https://datatab.de/tutorial/k-means-clusteranalyse
